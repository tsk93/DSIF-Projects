# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: An Analysis of Singapore's Weather to Optimise Resource Management in the Automotive Maintenance Industry

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# According to the [Meteorological Services Singapore](http://www.weather.gov.sg/climate-climate-of-singapore/#:~:text=Singapore%20is%20situated%20near%20the,month%2Dto%2Dmonth%20variation.), Singapore has typical tropical climate with adundant rainfall, high and uniform temperatures and high humidity all year round, since its situated near the equator. There are many factors that help us understand the climate of a country and in this project we are going to look into a few, especially rainfall.
#
# Singapore’s climate is characterised by two main monsoon seasons separated by inter-monsoonal periods.  The **Northeast Monsoon** occurs from December to early March, and the **Southwest Monsoon** from June to September.
#
# The major weather systems affecting Singapore that can lead to heavy rainfall are:
#
# -Monsoon surges, or strong wind episodes in the Northeast Monsoon flow bringing about major rainfall events;
#
# -Sumatra squalls, an organised line of thunderstorms travelling eastward across Singapore, having developed over the island of Sumatra or Straits of Malacca west of us;
#
# -Afternoon and evening thunderstorms caused by strong surface heating and by the sea breeze circulation that develops in the afternoon.
#
# Singapore’s climate station has been located at several different sites in the past 140 years. The station had been decommissioned at various points in the past due to changes to local land use in the site’s vicinity, and had to be relocated. Since 1984, the climate station has been located at **Changi**.
#
# There are other metrics of climate such as temperature, humidity, sun shine duration, wind speed, cloud cover etc. All the dataset used in the project comes from [data.gov.sg](data.gov.sg), as recorded at the Changi climate station

# %% [markdown]
# ### Choose your Data
#
# There are 2 datasets included in the [`data`](./data/) folder for this project. These correponds to rainfall information.
#
# * [`rainfall-monthly-number-of-rain-days.csv`](./data/rainfall-monthly-number-of-rain-days.csv): Monthly number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.
# * [`rainfall-monthly-total.csv`](./data/rainfall-monthly-total.csv): Monthly total rain recorded in mm(millimeters) from 1982 to 2022
#
# Other relevant weather datasets from [data.gov.sg](data.gov.sg) that you can download and use are as follows:
#
# * [Relative Humidity](https://data.gov.sg/dataset/relative-humidity-monthly-mean)
# * [Monthly Maximum Daily Rainfall](https://data.gov.sg/dataset/rainfall-monthly-maximum-daily-total)
# * [Hourly wet buld temperature](https://data.gov.sg/dataset/wet-bulb-temperature-hourly)
# * [Monthly mean sunshine hours](https://data.gov.sg/dataset/sunshine-duration-monthly-mean-daily-duration)
# * [Surface Air Temperature](https://data.gov.sg/dataset/surface-air-temperature-mean-daily-minimum)
#
# You can also use other datasets for your analysis, make sure to cite the source when you are using them

# %% [markdown]
# Data taken from <a href="https://data.gov.sg/">data.gov.sg</a>:
#
# rainfall-monthly-number-of-rain-days.csv: Number of rainy days per month
#
# rainfall-monthly-total.csv: Monthly total rainfall in mm
#
# rainfall-monthly-highest-daily-total.csv: Highest rainfall in a day in a month
#
# relative-humidity-monthly-mean.csv: Monthly mean relative humidity
#
# sunshine-duration-monthly-mean-daily-duration.csv Mean daily sunshine duration in a month
#
# surface-air-temperature-monthly-mean-daily-minimum.csv: Mean daily minimum air temperature in a month
#
# surface-air-temperature-monthly-mean-daily-maximum.csv: Mean daily maximum air temperature in a month
#
# surface-air-temperature-monthly-mean.csv: Mean air temperature in a month

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# You are working in the automotive repair and maintenance industry, where your clients are mostly car owners that rely on internal combustion engines (i.e. gasoline-powered cars). As the Singapore government aims to <a href="https://www.channelnewsasia.com/singapore/budget-2020-additional-incentives-encourage-use-more-environmentally-friendly-vehicles-1338721">move towards the usage of environmentally friendly vehicles by 2040</a>, your boss has tasked you with the responsbility of exploring cost optimisation measures while the management plans to <a href='https://www.ema.gov.sg/media_release.aspx?news_sid=202210248ax0PeHUaGcm'>upskill its employees in the clean energy sector</a> to be ready for Singapore’s transition towards cleaner energy. By analysing historical weather data, this project aims to allow your company to implement strategies that complement Singapore's weather all year round, in terms of manpower and inventory management.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on how climate change is affecting different industries or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# * Despite <a href="https://www.straitstimes.com/singapore/transport/coe-premiums-at-all-time-highs-in-2022-buyers-could-get-slight-reprieve-in-later-half-of-2023"> exorbitant Certificate of Entitlement (COE) prices</a> that aim to deter potential buyers, the number of cars in Singapore remains <a href="https://tablebuilder.singstat.gov.sg/table/TS/M650271"> significantly high </a> over the years. This bodes well for the automotive repair and maintenance industry due to a large customer pool, regardless of weather conditions all year round.
#
# * Weather conditions can affect the performance of motor vehicles, for instance humidity can <a href="https://www.foxrunauto.com/blog/how-summer-heat-and-humidity-affects-your-car">affect the performance of motor engines</a> and rain can potentially <a href="https://www.autodeal.com.ph/articles/car-features/how-can-rain-damage-my-car">affect a vehicle's exterior condition</a>.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
#manually calculate mean
def average(numbers):
    sum=0
    if (type(numbers)==list or type(numbers)==tuple) and set([type(x) for x in numbers]) in [{int},{float},{int,float}]:
        for i in numbers:
            sum+=i
        return round(float(sum/len(numbers)),4)
    else:
        return "Please check input, requires a list or tuple of numeric data."

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# manually calculate std dev
def stddev(numbers):    
    residual=0
    if (type(numbers)==list or type(numbers)==tuple) and set([type(x) for x in numbers]) in [{int},{float},{int,float}]:
        u=average(numbers)
        for i in numbers:
            residual+=((i-u)**2)
        return round(float((residual/len(numbers))**(0.5)),4)
    else:
        return "Please check input, requires a list or tuple of numeric data."

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import calendar

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import all the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary. Make sure to comment your code to showcase the intent behind the data processing step.
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values and datatype.
# 3. Check for any obvious issues with the observations.
# 4. Fix any errors you identified in steps 2-3.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If the month column data is better analyzed as month and year, create new columns for the same
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
#     - Since different climate metrics are in month format, you can merge them into one single dataframe for easier analysis
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# import data
monthly_rainy_days=pd.read_csv("../data/rainfall-monthly-number-of-rain-days.csv")
monthly_daily_highest_rainfall=pd.read_csv("../data/rainfall-monthly-highest-daily-total.csv")
monthly_total_rainfall=pd.read_csv("../data/rainfall-monthly-total.csv")
monthly_mean_relative_humidity=pd.read_csv("../data/relative-humidity-monthly-mean.csv")
monthly_mean_sunshine_hours=pd.read_csv("../data/sunshine-duration-monthly-mean-daily-duration.csv")
monthly_mean_air_temperature=pd.read_csv("../data/surface-air-temperature-monthly-mean.csv")
monthly_mean_daily_maximum_air_temp=pd.read_csv("../data/surface-air-temperature-monthly-mean-daily-maximum.csv")
monthly_mean_daily_minimum_air_temp=pd.read_csv("../data/surface-air-temperature-monthly-mean-daily-minimum.csv")

#print first 5 rows of each dataframe
dataset=[monthly_rainy_days,monthly_daily_highest_rainfall,monthly_total_rainfall,monthly_mean_relative_humidity,monthly_mean_sunshine_hours,monthly_mean_air_temperature,monthly_mean_daily_maximum_air_temp,monthly_mean_daily_minimum_air_temp]
for i in dataset:
    print(i.head())
    print('-'*50)
# Out:
#      month  no_of_rainy_days
# 0  1982-01                10
# 1  1982-02                 5
# 2  1982-03                11
# 3  1982-04                14
# 4  1982-05                10
# --------------------------------------------------
#      month  maximum_rainfall_in_a_day
# 0  1982-01                       36.5
# 1  1982-02                        9.4
# 2  1982-03                       61.7
# 3  1982-04                       45.1
# 4  1982-05                       33.0
# --------------------------------------------------
#      month  total_rainfall
# 0  1982-01           107.1
# 1  1982-02            27.8
# 2  1982-03           160.8
# 3  1982-04           157.0
# 4  1982-05           102.2
# --------------------------------------------------
#      month  mean_rh
# 0  1982-01     81.2
# 1  1982-02     79.5
# 2  1982-03     82.3
# 3  1982-04     85.9
# 4  1982-05     83.2
# --------------------------------------------------
#      month  mean_sunshine_hrs
# ...

# %% [markdown]
# No issues observed with printing the first 5 rows of each dataset.

# %%
# Check datatype and nulls in each dataframe
for i in dataset:
    print(f"Datatype:")
    print(i.info(),end="\n\n")
    print("Number of null values:")
    print(i.isnull().sum())
    print('-'*50)
# Out:
# Datatype:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month             491 non-null    object
#  1   no_of_rainy_days  491 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8+ KB
# None
#
# Number of null values:
# month               0
# no_of_rainy_days    0
# dtype: int64
# --------------------------------------------------
# Datatype:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      491 non-null    object
#  1   maximum_rainfall_in_a_day  491 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.8+ KB
# None
#
# Number of null values:
# month                        0
# ...

# %% [markdown]
# No nulls and data type mismatch observed in each dataset.

# %%
#creating a separate month and year column for each dataframe
def rename_month(x):
    if type(x)!=pd.DataFrame or 'month' not in x.columns:
        return "Please check input, Pandas dataframe required."
    else:
        x.rename(columns={"month":"year_month"},inplace=True)
        x["year"]=x["year_month"].map(lambda x: int(x[0:4]))
        x["month_num"]=x["year_month"].map(lambda x: int(x[-1]) if x[-2:-1]=='0' else int(x[-2:]))
        x["month"]=x["month_num"].map(lambda x: calendar.month_abbr[int(x)])

for i in dataset:
    rename_month(i)
    print("Datatype:")
    print(i.info(),end="\n\n")
    print("Number of null values:")
    print(i.isnull().sum())
    print('-'*50)
# Out:
# Datatype:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year_month        491 non-null    object
#  1   no_of_rainy_days  491 non-null    int64
#  2   year              491 non-null    int64
#  3   month_num         491 non-null    int64
#  4   month             491 non-null    object
# dtypes: int64(3), object(2)
# memory usage: 19.3+ KB
# None
#
# Number of null values:
# year_month          0
# no_of_rainy_days    0
# year                0
# month_num           0
# month               0
# dtype: int64
# --------------------------------------------------
# Datatype:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
# ...

# %% [markdown]
# This function aims to create a numeric month (1 to 12) column, a numeric year column and a non-numeric month column (Jan to Dec).

# %%
#merge dataframes
weather_df=dataset[0]
for i in range(len(dataset)-1):
    weather_df=pd.merge(weather_df,dataset[i+1], how='left')

#reorder final dataframe    
df=weather_df.columns.tolist()
df2=[df[0]]+df[2:5]+[df[1]]+df[5:]
weather_df=weather_df[df2]
weather_df.head()
print("Datatype:")
print(weather_df.info(),end="\n\n")
print("Number of null values:")
print(weather_df.isnull().sum())
print('-'*50)
# Out:
# Datatype:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 0 to 490
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year_month                 491 non-null    object
#  1   year                       491 non-null    int64
#  2   month_num                  491 non-null    int64
#  3   month                      491 non-null    object
#  4   no_of_rainy_days           491 non-null    int64
#  5   maximum_rainfall_in_a_day  491 non-null    float64
#  6   total_rainfall             491 non-null    float64
#  7   mean_rh                    491 non-null    float64
#  8   mean_sunshine_hrs          491 non-null    float64
#  9   mean_temp                  491 non-null    float64
#  10  temp_mean_daily_max        491 non-null    float64
#  11  temp_mean_daily_min        491 non-null    float64
# dtypes: float64(7), int64(3), object(2)
# memory usage: 49.9+ KB
# None
#
# ...

# %% [markdown]
# Final check on merged weather dataset does not reveal any nulls and the datatype is correct in each column.

# %%
#rename merged dataset columns and save to csv
weather_df.rename(columns={"no_of_rainy_days": "rainy_days", "maximum_rainfall_in_a_day": "highest_daily_rainfall","mean_rh":"mean_relative_humidity","mean_sunshine_hrs":"mean_sunshine_hours"},inplace=True)
weather_df.to_csv("../data/weather.csv",index=False)
weather_df.head()
# Out:
#   year_month  year  month_num month  rainy_days  highest_daily_rainfall  \
# 0    1982-01  1982          1   Jan          10                    36.5
# 1    1982-02  1982          2   Feb           5                     9.4
# 2    1982-03  1982          3   Mar          11                    61.7
# 3    1982-04  1982          4   Apr          14                    45.1
# 4    1982-05  1982          5   May          10                    33.0
#
#    total_rainfall  mean_relative_humidity  mean_sunshine_hours  mean_temp  \
# 0           107.1                    81.2                  5.6       25.9
# 1            27.8                    79.5                  7.6       27.1
# 2           160.8                    82.3                  5.1       27.2
# 3           157.0                    85.9                  4.7       27.0
# 4           102.2                    83.2                  5.8       28.0
#
#    temp_mean_daily_max  temp_mean_daily_min
# ...

# %% [markdown]
# Merged dataset is working fine.

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# Data dictionary for weather dataset:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |rainy_days|int|rainfall-monthly-number-of-rain-days|Number of rainy days|
# |highest_daily_rainfall|float|rainfall-monthly-highest-daily-total|Highest daily rainfall in a month in mm|
# |total_rainfall|float|rainfall-monthly-total|Total rainfall in mm|
# |mean_relative_humidity|float|relative-humidity-monthly-mean.csv|Mean relative humidity|
# |mean_sunshine_hours|float|sunshine-duration-monthly-mean-daily-duration|Mean daily sunshine duration in a month in hours|
# |mean_temp|float|surface-air-temperature-monthly-mean|Mean air temperature in a month in °C|
# |temp_mean_daily_max|float|surface-air-temperature-monthly-mean-daily-maximum|Mean daily maximum air temperature in a month in °C|
# |temp_mean_daily_min|float|surface-air-temperature-monthly-mean-daily-minimum|Mean daily minimum air temperature in a month in °C|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'rainfall-monthly-total': xxx, 'no_of_rainy_days': xxx, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which month have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest total rainfall in the date range of analysis?
#         - Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest number of rainy days in the date range of analysis?
#         - Are there any outliers months in the dataset?
#
#     - **The above 5 questions are compulsory. Feel free to explore other trends based on the datasets that you have choosen for analysis. You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#summary statistics
weather_df.describe()
# Out:
#               year   month_num  rainy_days  highest_daily_rainfall  \
# count   491.000000  491.000000  491.000000              491.000000
# mean   2001.959267    6.488798   14.112016               52.277189
# std      11.821736    3.450137    4.995680               35.647758
# min    1982.000000    1.000000    1.000000                0.200000
# 25%    1992.000000    3.500000   11.000000               30.800000
# 50%    2002.000000    6.000000   14.000000               43.800000
# 75%    2012.000000    9.000000   18.000000               62.850000
# max    2022.000000   12.000000   27.000000              216.200000
#
#        total_rainfall  mean_relative_humidity  mean_sunshine_hours  \
# count      491.000000              491.000000           491.000000
# mean       177.537067               82.224644             5.676171
# std        113.856895                3.417366             1.212024
# min          0.200000               72.000000             2.700000
# ...

# %%
#Dictionary comprehension to calculate standard deviation from function to each column
print({x:stddev(weather_df[x].values.tolist()) for x in weather_df.columns[4:]})
# Out:
# {'rainy_days': 4.9906, 'highest_daily_rainfall': 35.6114, 'total_rainfall': 113.7409, 'mean_relative_humidity': 3.4139, 'mean_sunshine_hours': 1.2108, 'mean_temp': 0.7991, 'temp_mean_daily_max': 0.8649, 'temp_mean_daily_min': 0.7328}

# %%
# Which months have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?
years=[1990,2000,2010,2020]
import calendar
for i in years:  
    print(f"Year {i}:")
    rainfall=weather_df[weather_df['year']==i].sort_values(by='total_rainfall',ascending=False)
    print(rainfall.iloc[[0,-1],:][['month','total_rainfall']].reset_index(drop=True))
    print(f"In {i}, highest total rainfall occurred in {calendar.month_name[list(calendar.month_abbr).index(rainfall.head(1)['month'].values.tolist()[0])]} and lowest total rainfall occurred in {calendar.month_name[list(calendar.month_abbr).index(rainfall.tail(1)['month'].values.tolist()[0])]}.")
    print("-"*100)
# Out:
# Year 1990:
#   month  total_rainfall
# 0   Sep           204.5
# 1   Feb            24.1
# In 1990, highest total rainfall occurred in September and lowest total rainfall occurred in February.
# ----------------------------------------------------------------------------------------------------
# Year 2000:
#   month  total_rainfall
# 0   Nov           385.7
# 1   Sep            81.1
# In 2000, highest total rainfall occurred in November and lowest total rainfall occurred in September.
# ----------------------------------------------------------------------------------------------------
# Year 2010:
#   month  total_rainfall
# 0   Jul           298.5
# 1   Feb             6.3
# In 2010, highest total rainfall occurred in July and lowest total rainfall occurred in February.
# ----------------------------------------------------------------------------------------------------
# Year 2020:
#   month  total_rainfall
# 0   May           255.6
# 1   Feb            65.0
# ...

# %% [markdown]
# Below table shows the months which recorded the highest and lowest total rainfall in 1990, 2000, 2010 and 2020.
#
# | Year | Highest total rainfall | Lowest total rainfall |
# | --- | --- | --- |
# | 1990 | September | February |
# | 2000 | November  | September |
# | 2010 | July | February |
# | 2020 | May | February |

# %% [markdown]
# It appears that highest total rainfall occurs mainly at the second half of the year (July-December), and lowest total rainfall occurs mainly at the first half of the year (January-June).

# %%
# Which years have the highest and lowest total rainfall in the date range of analysis?
rainfall_by_year=weather_df.groupby('year').sum()[['total_rainfall']].sort_values(by="total_rainfall",ascending=False)
rainfall_by_year.iloc[[0,-1],:]
# Out:
#       total_rainfall
# year
# 2007          2886.2
# 1997          1118.9

# %% [markdown]
# Highest total rainfall observed in 2007, whereas lowest total rainfall observed in 1997.

# %%
# Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?

years=[1990,2000,2010,2020]
for i in years:  
    print(f"Year {i}:")
    rainy_days=weather_df[weather_df['year']==i].sort_values(by='rainy_days',ascending=False)
    print(rainy_days.iloc[[0,-1],:][['month','rainy_days']].reset_index(drop=True))
    print(f"In {i}, highest and lowest number of rain days occurred in {calendar.month_name[list(calendar.month_abbr).index(rainy_days.head(1)['month'].values.tolist()[0])]} and {calendar.month_name[list(calendar.month_abbr).index(rainy_days.tail(1)['month'].values.tolist()[0])]} respectively.")
    print("-"*100)
# Out:
# Year 1990:
#   month  rainy_days
# 0   Sep          17
# 1   Mar           4
# In 1990, highest and lowest number of rain days occurred in September and March respectively.
# ----------------------------------------------------------------------------------------------------
# Year 2000:
#   month  rainy_days
# 0   Nov          21
# 1   May          10
# In 2000, highest and lowest number of rain days occurred in November and May respectively.
# ----------------------------------------------------------------------------------------------------
# Year 2010:
#   month  rainy_days
# 0   Nov          21
# 1   Feb           4
# In 2010, highest and lowest number of rain days occurred in November and February respectively.
# ----------------------------------------------------------------------------------------------------
# Year 2020:
#   month  rainy_days
# 0   Jul          22
# 1   Jan           6
# ...

# %% [markdown]
# Below table shows the months which recorded the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020.
#
# | Year |Most rainy days | Least rainy days |
# | --- | --- | --- |
# | 1990 | September | March|
# | 2000 | November  | May |
# | 2010 | November | February |
# | 2020 | July | January |

# %% [markdown]
# Likewise, it appears that rainy days mostly take place in the second half of the year (July-December), and the least number of rainy days happen in the first half of the year (January-June). This resembles the total rainfall observation to a certain extent.

# %%
# Which year have the highest and lowest number of rainy days in the date range of analysis?
rainy_days_by_year=weather_df.groupby('year').sum()[['rainy_days']].sort_values(by="rainy_days",ascending=False)
rainy_days_by_year.iloc[[0,-1],:]
# Out:
#       rainy_days
# year
# 2013         206
# 1997         116

# %% [markdown]
# Highest number of rainy days observed in 2013, whereas lowest number of rainy days observed in 1997.
#
# Lowest number of rainy days in a year is likely to have the lowest annual rainfall, but this might not necessarily be true between highest number of rainy days and highest annual rainfall.

# %%
# Are there any outliers months in the dataset?
fig, axes = plt.subplots(3, 3, figsize=(18, 18))
i=weather_df.columns[4:]
sns.boxplot(ax=axes[0,0],data=weather_df.loc[:,['month',i[0]]],y='month',x=i[0]).set(xlabel='Number of rainy days',ylabel='Month')
sns.boxplot(ax=axes[0,1],data=weather_df.loc[:,['month',i[1]]],y='month',x=i[1]).set(xlabel='Highest daily rainfall',ylabel='Month')
sns.boxplot(ax=axes[0,2],data=weather_df.loc[:,['month',i[2]]],y='month',x=i[2]).set(xlabel='Total rainfall',ylabel='Month')
sns.boxplot(ax=axes[1,0],data=weather_df.loc[:,['month',i[3]]],y='month',x=i[3]).set(xlabel='Mean relative humidity',ylabel='Month')
sns.boxplot(ax=axes[1,1],data=weather_df.loc[:,['month',i[4]]],y='month',x=i[4]).set(xlabel='Mean sunshine hours',ylabel='Month')
sns.boxplot(ax=axes[1,2],data=weather_df.loc[:,['month',i[5]]],y='month',x=i[5]).set(xlabel='Mean temperature',ylabel='Month')
sns.boxplot(ax=axes[2,0],data=weather_df.loc[:,['month',i[6]]],y='month',x=i[6]).set(xlabel='Mean daily maximum temperature',ylabel='Month')
sns.boxplot(ax=axes[2,1],data=weather_df.loc[:,['month',i[7]]],y='month',x=i[7]).set(xlabel='Mean daily minimum temperature ',ylabel='Month')
fig.delaxes(axes[2][2])
plt.show()

# %% [markdown]
# By visualising each weather metric with a boxplot, we observe that each metric tells us a different story. For instance, we observe minimal outliers in mean sunshine hours, mean air temperature, number of rainy days and mean daily maximum temperature. The other weather metrics have outliers present in 6 or more different months. Based on the last 20 years, May and September appear to have the most outliers after examining all the boxplots.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# Some ideas for plots that can be generated:
#
# - Plot the histogram of the rainfall data with various bins and comment on the distribution of the data - is it centered, skewed?
# - Plot the box-and-whiskers plot. Comment on the different quartiles and identify any outliers in the dataset.
# - Is there a correlation between the number of rainy days and total rainfall in the month? What kind of correlation do your suspect? Does the graph show the same?

# %%
# Using a heatmap to check for correlation between different weather conditions
plt.figure(figsize=(12,8))
plt.title('Weather correlation data from 1982 to 2022')
corr=weather_df.iloc[:,4:].corr()
matrix = np.triu(weather_df.iloc[:,4:].corr()) # obtain upper triangular matrix of correlation coeefficients
sns.heatmap(corr,mask=matrix,annot=True,square=True,cmap='gist_heat',vmin=-1, vmax=1,fmt='.3f',center= 0,linewidth=1) # labelling correlation coefficents
plt.show()

# %% [markdown]
# From the above heatmap plot, rainfall appears to be positively correlated to humidity and number of rainy days. Amount of sunshine appears to be positively correlated to temperature as well. On the other hand, amount of sunshine and temperature appear to be negatively correlated to rainfall and humidity data.

# %%
fig, axes = plt.subplots(3, 3, figsize=(18, 18))
i=weather_df.columns[4:]
sns.histplot(ax=axes[0,0],data=weather_df.loc[:,['month',i[0]]]).set(xlabel='Number of rainy days',ylabel='Count')
axes[0,0].axvline(x=weather_df[i[0]].median(),color='red',linestyle='dashed',alpha=0.7)
sns.histplot(ax=axes[0,1],data=weather_df.loc[:,['month',i[1]]]).set(xlabel='Highest daily rainfall',ylabel='Count')
axes[0,1].axvline(x=weather_df[i[1]].median(),color='red',linestyle='dashed',alpha=0.7)
sns.histplot(ax=axes[0,2],data=weather_df.loc[:,['month',i[2]]]).set(xlabel='Total rainfall',ylabel='Count')
axes[0,2].axvline(x=weather_df[i[2]].median(),color='red',linestyle='dashed',alpha=0.7)
sns.histplot(ax=axes[1,0],data=weather_df.loc[:,['month',i[3]]]).set(xlabel='Mean relative humidity',ylabel='Count')
axes[1,0].axvline(x=weather_df[i[3]].median(),color='red',linestyle='dashed',alpha=0.7)
sns.histplot(ax=axes[1,1],data=weather_df.loc[:,['month',i[4]]]).set(xlabel='Mean sunshine hours',ylabel='Count')
axes[1,1].axvline(x=weather_df[i[4]].median(),color='red',linestyle='dashed',alpha=0.7)
sns.histplot(ax=axes[1,2],data=weather_df.loc[:,['month',i[5]]]).set(xlabel='Mean temperature',ylabel='Count')
axes[1,2].axvline(x=weather_df[i[5]].median(),color='red',linestyle='dashed',alpha=0.7)
sns.histplot(ax=axes[2,0],data=weather_df.loc[:,['month',i[6]]]).set(xlabel='Mean daily maximum temperature',ylabel='Count')
axes[2,0].axvline(x=weather_df[i[6]].median(),color='red',linestyle='dashed',alpha=0.7)
sns.histplot(ax=axes[2,1],data=weather_df.loc[:,['month',i[7]]]).set(xlabel='Mean daily minimum temperature',ylabel='Count')
axes[2,1].axvline(x=weather_df[i[7]].median(),color='red',linestyle='dashed',alpha=0.7)
fig.delaxes(axes[2][2])
plt.show()

# %% [markdown]
# From above histogram plots (where red line denotes median), most of them approximate a normal distribution. However there are some exceptions, we observe that total rainfall and highest daily rainfall are right skewed and relative humidity is slightly left skewed. This makes sense as the air becomes more humid (i.e. higher amount of water vapour in the air) during rainy days. Generally it is preferred to transform or normalise skewed data to minimise bias.

# %%
fig, axes = plt.subplots(2,3,figsize=(18, 12))
sns.boxplot(ax=axes[0,0],data=weather_df[['temp_mean_daily_max','mean_temp', 'temp_mean_daily_min']]).set(ylabel='Temperature',title='Temperature (°C)')
sns.boxplot(ax=axes[0,1],data=weather_df[['total_rainfall','highest_daily_rainfall']]).set(ylabel='Rainfall',title='Rainfall (mm)')
sns.boxplot(ax=axes[0,2],data=weather_df[['mean_relative_humidity']]).set(ylabel='Humidity',title='Relative humidity (%)')
sns.boxplot(ax=axes[1,0],data=weather_df[['mean_sunshine_hours']]).set(ylabel='Sunshine hours',title='Monthly sunshine (hours)')
sns.boxplot(ax=axes[1,1],data=weather_df[['rainy_days']]).set(ylabel='Rainy days',title='Rainy days')
fig.delaxes(axes[1][2])
plt.show()

# %% [markdown]
# Most outliers observed on rainfall boxplots, which makes sense as the histograms are right skewed. Minimal or no outliers observed on other boxplots.

# %%
#corr btw rainfall and no. of rainy days

plt.figure(figsize = (6, 4))
plt.scatter(weather_df['rainy_days'],weather_df['total_rainfall'])
plt.title('Correlation between monthly total rainfall and rainy days')
plt.xlabel('Number of rainy days')
plt.ylabel('Monthly total rainfall')
plt.show()

# %% [markdown]
# Higher total rainfall is generally observed as number of rainy days increase in a month.

# %%
plt.figure(figsize = (6, 4))
plt.scatter(weather_df['rainy_days'],weather_df['highest_daily_rainfall'])
plt.xlabel('Number of rainy days')
plt.ylabel('Monthly highest daily rainfall')
plt.title('Correlation between monthly highest daily rainfall and number of rainy days')
plt.show()

# %% [markdown]
# Monthly highest daily rainfall is generally observed as number of rainy days increase in a month.

# %%
#corr btw sunshine and rainfall

plt.figure(figsize = (6, 4))
plt.scatter(weather_df['mean_sunshine_hours'],weather_df['total_rainfall'])
plt.ylabel('Rainfall')
plt.xlabel('Mean sunshine hours')
plt.title('Correlation between monthly total rainfall and sunshine hours')
plt.show()

# %% [markdown]
# Higher total rainfall is generally observed as mean sunshine hours decrease in a month. This makes sense as significant cloud cover will reflect sunlight away from us.

# %%
#corr btw sunshine and rainy days

plt.figure(figsize = (6, 4))
plt.scatter(weather_df['mean_relative_humidity'],weather_df['total_rainfall'])
plt.xlabel('Mean relative humidity')
plt.ylabel('Total rainfall')
plt.title('Correlation between monthly total rainfall and mean relative humidity')
plt.show()

# %% [markdown]
# Higher total rainfall is generally observed as mean relative humidity increases in a month. This makes sense as the air becomes more humid (i.e. higher amount of water vapour in the air) during rainy conditions.

# %%
plt.figure(figsize = (6, 4))
plt.scatter(weather_df['mean_relative_humidity'],weather_df['mean_temp'])
plt.xlabel('Mean Relative Humidity')
plt.ylabel('Mean Temperature')
plt.title('Correlation between mean temperature and mean relative humidity')
plt.show()

# %% [markdown]
# Lower mean temperature is generally observed as mean relative humidity increases in a month. This makes sense our surroundings become cooler during rainy conditions.

# %%
plt.figure(figsize = (6, 4))
plt.scatter(weather_df['mean_sunshine_hours'],weather_df['mean_temp'])
plt.xlabel('Mean sunshine hours')
plt.ylabel('Mean Temperature')
plt.title('Correlation between mean temperature and mean sunshine hours')
plt.show()

# %% [markdown]
# Higher mean temperature is generally observed as mean sunshine hours increases in a month. This makes sense temperatures are higher on a sunny day.

# %%
#plt.figure(figsize = (25, 9))
#data=weather_df[['year','mean_temp','max_temperature','temp_extremes_min']]
#plt.scatter(data['year'],data['max_temperature'],label = 'absolute_max_temperature')
#plt.scatter(data['year'],data['mean_temp'],label = 'mean_temp')                     
#plt.scatter(data['year'],data['temp_extremes_min'],label='absolute_min_temperature')
#plt.legend(loc = 'upper right')

# %%
#fig, axs = plt.subplots(3, 1, figsize=(24, 20), sharex=True)
#sns.boxplot(y=weather_df['max_temperature'], x=weather_df['year'], ax=axs[0])
#sns.boxplot(y=weather_df['mean_temp'], x=weather_df['year'], ax=axs[1])
#sns.boxplot(y=weather_df['temp_extremes_min'], x=weather_df['year'], ax=axs[2])
#fig.suptitle("Box plots of daily temperatures in Singapore; 1982 - 2022 ", fontsize=20)
#axs[0].set_ylabel("Maximum Temperature (°C)", fontsize=15)
#axs[1].set_ylabel("Mean Temperature (°C)", fontsize=15)
#axs[2].set_ylabel("Minimum Temperature (°C)", fontsize=15)
#plt.show()

#fig, axes = plt.subplots(9, figsize=(24, 100), sharex=True)    

#for i in range(4,13):
    #sns.boxplot(y=weather_df[weather_df.columns[i]], x=weather_df["month_num"], ax=axes[i-4])
    #sns.boxplot(weather_df[['year','month_num', weather_df.columns[i]]].pivot('month_num','year', weather_df.columns[i]),linewidths=0.5,cmap="icefire",center=27,ax=axes[i-4])
    #axes[i-4].set_ylabel(weather_df.columns[i], fontsize=15)
    #axes[i-4].set_xlabel("Month", fontsize=15)
    #axes[i-4].set_title(weather_df.columns[i])
    #axes[i-4].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],fontsize=12)
#plt.show()

# %%
#plt.figure(figsize=(20,10))
#plt.bar(x=weather_df['year'].unique(),height=weather_df.groupby(['year'])['no_of_rainy_days'].sum())
#plt.title('Yearly rainfall in Singapore; 1982-2022', fontsize=20)
#plt.xlabel("Year", fontsize=12)
#plt.xticks(ticks=weather_df['year'].unique(),rotation=90)
#plt.ylabel("Rainy days", fontsize=12)
#plt.show()

# %%
#plt.figure(figsize=(20,10))
#plt.bar(x=weather_df['year'].unique(),height=weather_df.groupby(['year'])['total_rainfall'].sum())
#plt.title('Yearly rainfall in Singapore; 1982-2022', fontsize=20)
#plt.xlabel("Year", fontsize=12)
#plt.xticks(ticks=weather_df['year'].unique(),rotation=90)
#plt.ylabel("Total yearly rainfall (mm)", fontsize=12)
#plt.show()

# %%
fig, axes = plt.subplots(9, figsize=(28, 100), sharey=True)    

for i in range(4,13):
    sns.heatmap(weather_df[['year','month_num', weather_df.columns[i]]].pivot('month_num','year', weather_df.columns[i]),linewidths=0.5,cmap="icefire",center=27,ax=axes[i-4])
    axes[i-4].set_xlabel("Year", fontsize=15)
    axes[i-4].set_ylabel("Month", fontsize=15)
    axes[i-4].set_title(weather_df.columns[i])
    axes[i-4].set_yticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],fontsize=12)

#sns.heatmap(weather_df[['year','month_num', weather_df.columns[4]]].pivot('month_num','year', weather_df.columns[4]),linewidths=0.5,cmap="YlOrRd",center=27,ax=axes[0,0])
#sns.heatmap(weather_df[['year','month_num', weather_df.columns[5]]].pivot('month_num','year', weather_df.columns[5]),linewidths=0.5,cmap="YlOrRd",center=27,ax=axes[0,1])
#sns.heatmap(weather_df[['year','month_num', weather_df.columns[6]]].pivot('month_num','year', weather_df.columns[6]),linewidths=0.5,cmap="YlOrRd",center=27,ax=axes[1,0])
#sns.heatmap(weather_df[['year','month_num', weather_df.columns[7]]].pivot('month_num','year', weather_df.columns[7]),linewidths=0.5,cmap="YlOrRd",center=27,ax=axes[1,1])
#sns.heatmap(weather_df[['year','month_num', weather_df.columns[8]]].pivot('month_num','year', weather_df.columns[8]),linewidths=0.5,cmap="YlOrRd",center=27,ax=axes[2,0])
#sns.heatmap(weather_df[['year','month_num', weather_df.columns[9]]].pivot('month_num','year', weather_df.columns[9]),linewidths=0.5,cmap="YlOrRd",center=27,ax=axes[2,1])
#sns.heatmap(weather_df[['year','month_num', weather_df.columns[10]]].pivot('month_num','year', weather_df.columns[10]),linewidths=0.5,cmap="YlOrRd",center=27,ax=axes[3,0])
#sns.heatmap(weather_df[['year','month_num', weather_df.columns[11]]].pivot('month_num','year', weather_df.columns[11]),linewidths=0.5,cmap="YlOrRd",center=27,ax=axes[3,1])
#sns.heatmap(weather_df[['year','month_num', weather_df.columns[12]]].pivot('month_num','year', weather_df.columns[12]),linewidths=0.5,cmap="YlOrRd",center=27,ax=axes[4,0])


#fig.suptitle("Heatmap of various weather elements", fontsize=20)

#[axes[i,j].set_ylabel("Month", fontsize=15) for i in range(5) for j in range(2)]
#[(axes[i,j].set_yticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],fontsize=12)) for i in range(5) for j in range(2)]
#fig.tight_layout()
plt.show()

# %%
#fig, axes = plt.subplots(9, figsize=(28, 100), sharey=True)
#axis[0,1].scatter(x=weather_df.iloc[:,4], y=weather_df.iloc[:,5])

#  for i in range(4,13):
#    sns.heatmap(weather_df[['year','month_num', weather_df.columns[i]]].pivot('month_num','year', weather_df.columns[i]),linewidths=0.5,cmap="icefire",center=27,ax=axes[i-4])
#    axes[i-4].set_xlabel("Year", fontsize=15)
#    axes[i-4].set_ylabel("Month", fontsize=15)
#    axes[i-4].set_title(weather_df.columns[i])
#    axes[i-4].set_yticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],fontsize=12)

# for i in range(4,13):
#    sns.heatmap(weather_df[['year','month_num', weather_df.columns[i]]].pivot('month_num','year', weather_df.columns[i]),linewidths=0.5,cmap="icefire",center=27,ax=axes[i-4])
#    axes[i-4].set_xlabel("Year", fontsize=15)
#    axes[i-4].set_ylabel("Month", fontsize=15)
#    axes[i-4].set_title(weather_df.columns[i])
#    axes[i-4].set_yticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],fontsize=12)

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# Various weather elements are able to influence the performance and condition of motor vehicles, by examining Singapore's weather data, we are able to derive trends and relationships between these elements to understand the dominan
#
# poses both external (in the form of sea water submerging low lands) and internal problems (in the form of inability of water catchment and storm runoff to discharge the rain in time). While we could construct seawalls to ward of the effects of rising sea levels, we would not be able to control the amount of rain on our island. As seen from the EDAs, it seems that higher number of rainy days with higher amount of rainfall can be expected, this would in turn cause flooding on our island should our water catchment and storm water runoff are unable to handle it.
#
# We would recommend that the current capacity of the water catchments and storm water runoff systems to be review so that we are adequately prepared for this inevitability. We would also suggest on embarking an actual weather simulation with a complementary data science predictive model to complement the forecasting of future mean sea levels, and forecasting of rainfall on the island

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!

# %% [markdown]
# references:
#
# - https://data-flair.training/blogs/data-science-for-weather-prediction/
# - https://www.planalytics.com/article-4-ways-restaurants-leverage-weather-analytics/
# - https://www.restaurantdive.com/spons/4-ways-restaurants-leverage-weather-analytics/602085/
# - https://www.a-abana.com/about-us/blog/understand-how-weather-elements-affect-your-vehicle
# - https://sharpsheets.io/blog/auto-repair-profits-break-even/
# - https://www.ema.gov.sg/media_release.aspx?news_sid=202210248ax0PeHUaGcm
# - https://medium.com/@jonblackpixels/predicting-dengue-outbreaks-with-weather-data-pt-1-intro-and-eda-73d35aa11c4c
#
#
# - https://github.com/vyap2000/Data-Science-Projects-General-Assembly/blob/master/Project-2/VY_Project2.ipynb
# - https://github.com/xbno/DSI-Projects/blob/master/Project%202/proj-2-pres.ipynb
# - https://github.com/chawlasahaj/dsiprojects/blob/main/EDA-pandas-tableau/code/Project%201%20Code%20Sahaj%20Chawla.ipynb
# - https://github.com/anitaokoh/Understanding-the-Seaborn-heatmap-function/blob/master/dissecting_heatmap.ipynb
# - https://github.com/chuachinhon/weather_singapore_cch/tree/master/notebooks
#
# google search:
# - does humidity affect car performance
# - how does surface air temp affect a car's performance
# - singapore automotive industry
# - weather based marketing
# - weather analytics
# - how rainfall affects a car
# - profit margin of vehicle repair
# - tips to prolong a car lifespan
# - how does weather elements affect a car's condition
# - weather affects vehicle servicing
